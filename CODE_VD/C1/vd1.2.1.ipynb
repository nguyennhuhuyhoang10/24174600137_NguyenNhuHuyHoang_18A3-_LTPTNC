# %% [markdown]
# VD 1.2.1.1a

# %%
class Nhan_vien:
    id = 10
    name = "Nguyen Van A"
    age = 28
    def display(self):
        print(self.id, self.name, self.age)
# Ung dung
nv1 = Nhan_vien()
nv1.display()
# Out:
# 10 Nguyen Van A 28

# %% [markdown]
# VD1.2.1.1b

# %%
class Myclass:
    def __init__(self, value):
        self.value=value
    def my_method(self):
        print('Gia tri cua doi tuong :', self.value)
# Tao doi tuong tu lop Myclass
obj=Myclass(50) #Khai báo và khởi tạo đối tượng obj từ lớp Myclass
# Gọi phương thức my_method() của đối tượng obj
obj.my_method()
# Out:
# Gia tri cua doi tuong : 50

# %% [markdown]
# VD1.2.1.2

# %%
class Dog:
    DogCount=0
    def __init__(self, name, size, old, color):
        self.name=name
        self.size=size
        self.old=old
        self.color=color
    def Go(self):
        print("I'm going...")
    def Stay(self, place):
        print("I'm staying at {}".format(place))
    def Lie(self, place):
        print("I'm lyeing at {}".format(place))
    def Bark(self):
        print("Whoop...")
    def Eat(self, food):
        print("I'm eating {}".format(food))
    def Name(self):
        print("I'm {}".format(self.name))
# khởi tạo đối tượng
bull=Dog("Huy", "large", 2, "blue")
bull.Stay("house")
bull.Bark()
bull.Name()
# Out:
# I'm staying at house
# Whoop...
# I'm Huy

# %% [markdown]
# VD1.2.1.3. CONSTRCUTOR KHÔNG THAM SỐ:

# %%
class Dog:
    def __init__(self):
        print("Đây là constrcutor không có tham số")
    def display(self, name):
        print("Hello", name)
bull=Dog()
bull.display("The Dom")
# Out:
# Đây là constrcutor không có tham số
# Hello The Dom

# %% [markdown]
# VD1.2.1.4. CONSTRCOTOR CÓ THAM SỐ:

# %%
class Dog:
    def __init__(self, name):
        print("Đây là construtor có tham số")
        self.name=name
    def display(self):
        print("Hello", self.name)
bull=Dog("The Dom")
bull.display()
# Out:
# Đây là construtor có tham số
# Hello The Dom

# %% [markdown]
# VD1.2.1.6

# %%
class Dog:
# Class attributes
    DogCount = 0
    def __init__(self, name, size, age, color):
        self.name = name # object attributes
        self.size = size # object attributes
        self.age = age # object attributes
        self.color = color # object attributes
    def __del__(self):
        print("A dog object is being deleted.")
obj = Dog("bull", "large", 2, "yellow")
del obj
# Out:
# A dog object is being deleted.

# %% [markdown]
# VD1.2.1.7

# %%
class Dog:
# Class attributes
    DogCount = 0
    def __init__(self, name, size, age, color):
        self.name = name # object attributes
        self.size = size # object attributes
        self.age = age # object attributes
        self.color = color # object attributes
# tạo đối tượng của lớp Dog
bull = Dog("Dom", "large", 2, "yellow")
# in thuộc tính name của đối tượng bull
print(getattr(bull, 'name'))
# gán giá trị của age cho 3
setattr(bull, "age", 3)
# in giá trị của age
print(getattr(bull, 'age'))
# true nếu bull chứa thuộc tính large
print(hasattr(bull, 'name'))
# xóa thuộc tính age
delattr(bull, 'age')
# Kích hoạt lỗi nếu age đã bị xóa
print(bull.age)
# Out:
# Dom
# 3
# True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 22
#      20 delattr(bull, 'age')
#      21 # Kích hoạt lỗi nếu age đã bị xóa
# ---> 22 print(bull.age)
#
# AttributeError: 'Dog' object has no attribute 'age'

# %% [markdown]
# VD1.2.1.8

# %%
class Dog:
    def __init__(self, name, size, age, color):
        self.name = name # object attributes
        self.size = size # object attributes
        self.age = age # object attributes
        self.color = color # object attributes
    def display_details(self):
        print("Name:%s, size:%s, age:%s, color:%s" %(self.name, self.size, self.age,self.color))
bull=Dog("Dom", "large", 2, "yellow")
print(bull.__doc__)
print(bull.__dict__)
print(bull.__module__)
print(Dog.__name__)
# Out:
# None
# {'name': 'Dom', 'size': 'large', 'age': 2, 'color': 'yellow'}
# __main__
# Dog

# %% [markdown]
# VD1.2.1.10

# %%
class Dog:
    DogCount = 0
    def __init__(self, name, size, age, color):
        self.name = name #Thuộc tính đối tượng
        self.size = size
        self.age = age
        self.color = color
    @classmethod
    def CreateDog(cls, name, size, age, color):# Phương thức lớp để tạo đối tượng Dog thay vì dùng __init__
        cls.DogCount=cls.DogCount + 1 #Tăng giá trị của thuộc tính lớp DogCount lên 1
        return cls(name, size, age, color)
    @classmethod
    def get_dog_count(cls):
        return cls.DogCount
obj=Dog.CreateDog("bull", "large", 2, "yellow")
print("So luong doi tuong Dog da duoc tao:",Dog.get_dog_count())
obj2=Dog.CreateDog("poodle", "small", 1, "white")
print("So luong doi tuong Dog da duoc tao:",Dog.get_dog_count())
# Out:
# So luong doi tuong Dog da duoc tao: 1
# So luong doi tuong Dog da duoc tao: 2

# %% [markdown]
# VD1.2.1.11

# %%
class Dog:
    DogCount = 0 # Thuộc tính lớp
    def __init__(self, name, size, age, color):
        self.name = name # Thuộc tính đối tượng
        self.size = size #
        self.color = color #
        Dog.DogCount += 1 #
    @staticmethod
    def Report():
        print("Tong so doi tuong Dog:{}".format(Dog.DogCount))
dog1=Dog("Buddy", "Medium", 5, "Brown")
dog2=Dog("Max", "Small", 3, "Black")
dog1.Report()
# Out:
# Tong so doi tuong Dog:2

# %% [markdown]
# VD1.2.11.abc

# %%
class Dog:
    DogCount = 0   # Thuộc tính của lớp

    def __init__(self, name, size, age, color):
        self.name = name   # Thuộc tính đối tượng
        self.size = size   # Thuộc tính đối tượng
        self.age = age     # Thuộc tính đối tượng
        self.color = color # Thuộc tính đối tượng
        Dog.DogCount += 1  # Tăng bộ đếm (số lượng chó) lên 1 mỗi khi có đối tượng mới được tạo

    # Instance method: Phương thức đối tượng (dùng self)
    def show_count_instance(self):
        print(f"Số lượng đối tượng Dog đã được tạo [instance method] = {Dog.DogCount}")

    # Class method: Phương thức lớp (dùng cls)
    @classmethod
    def show_count_class(cls):
        print(f"Số lượng đối tượng Dog đã được tạo [class method] = {cls.DogCount}")

    # Static method: Phương thức tĩnh (không dùng self hay cls)
    @staticmethod
    def show_count_static():
        print(f"Số lượng đối tượng Dog đã được tạo [static method] = {Dog.DogCount}")
#UD
dog1=Dog("Buddy","Medium",5,"Brown")
