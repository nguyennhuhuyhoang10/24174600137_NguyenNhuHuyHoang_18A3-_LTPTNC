# %%
import xml.dom.minidom
def main():
    doc=xml.dom.minidom.parse("employee.xml")
    print(doc.nodeName)
    print(doc.firstChild.tagName)
if __name__=="__main__":
    main()
# Out:
# #document
# employee

# %% [markdown]
# VD2.1.3.2

# %%
import xml.dom.minidom 
 
def main(): 
       # use the parse() function to load and parse an XML file 
    doc = xml.dom.minidom.parse("employee.xml"); 
   
       # print out the document node and the name of the first child tag 
    print(doc.nodeName) 
    print(doc.documentElement.tagName) 
   
       # get a list of XML tags from the document and print each one 
    expertise = doc.getElementsByTagName("expertise") 
    print("%d expertise:" % expertise.length) 
    for skill in expertise: 
        print(skill.getAttribute("name")) 
if __name__=="__main__": 
    main()
# Out:
# #document
# employee
# 4 expertise:
# SQL
# Python
# Testing
# Business

# %% [markdown]
# vd2.1.3.3

# %%
import xml.dom.minidom 
 
def main(): 
       # use the parse() function to load and parse an XML file 
    doc = xml.dom.minidom.parse("employee.xml"); 
   
       # print out the document node and the name of the first child tag 
    print(doc.nodeName) 
    print(doc.documentElement.tagName) 
   
       # get a list of XML tags from the document and print each one 
    expertise = doc.getElementsByTagName("expertise") 
    print("%d expertise:" % expertise.length) 
    for skill in expertise: 
        print(skill.getAttribute("name"))
# Tạo một thẻ XML mới và thêm nó vào tài liệu
    newexpertise = doc.createElement("expertise") 
    newexpertise.setAttribute("name", "AI") 
    doc.firstChild.appendChild(newexpertise) 
    print(" ") 
    expertise = doc.getElementsByTagName("expertise") 
    print("%d expertise:" % expertise.length) 
    for skill in expertise: 
        print(skill.getAttribute("name"))
if __name__=="__main__": 
    main()
# Out:
# #document
# employee
# 4 expertise:
# SQL
# Python
# Testing
# Business
#
# 5 expertise:
# SQL
# Python
# Testing
# Business
# AI

# %% [markdown]
# vd2.1.4.1

# %%
import xml.etree.ElementTree as ET        #Bước 1      
 
tree = ET.parse('employee.xml')           #Bước 2 
 
root = tree.getroot()                      
name = root.find('name')                  #Bước 3 
print(name.text) 
 
expertise = root.find('expertise')        #Bước 4 
print(expertise.attrib['name']) 
 
city = root.find('city')                  #Bước 5 
print(city.text) 
 
newexpertise = ET.Element('expertise') 
newexpertise.attrib['name'] = 'XML'       #Bước 6 
root.append(newexpertise) 
 
tree.write('updated.xml', encoding='utf-8', xml_declaration=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 7
#       5 root = tree.getroot()
#       6 name = root.find('name')                  #Bước 3
# ----> 7 print(name.text)
#       9 expertise = root.find('expertise')        #Bước 4
#      10 print(expertise.attrib['name'])
#
# AttributeError: 'NoneType' object has no attribute 'text'
